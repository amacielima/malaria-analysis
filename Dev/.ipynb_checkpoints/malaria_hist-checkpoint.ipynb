# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
original_dataset = pd.read_csv('C:\\Users\\Amanda Maciel\\Desktop\\Mestrado\\PME406\\Trabalho Final\Datasets\\malaria-mosquito\\Africa_Vectors_database_1898-2016_cluster.csv', encoding='utf-8', sep=';')

df = original_dataset.iloc[:,9:35]

df.hist(bins=26, figsize = (15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028FA4B9F358>,
# ...
#       dtype=object)
